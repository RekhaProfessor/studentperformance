# %% [markdown]
# <a href="https://colab.research.google.com/github/RekhaProfessor/studentperformance/blob/main/studentperformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""colab_student_mark_analysis.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1VehS-5-Mbe1VwKFy20ctOn81cTIsyc-i

# Student Mark Analysis
This notebook analyzes student marks using Python and Pandas.
"""

import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('student_marks.csv')
df.head()

# Display basic information
print(df.info())
print('\nAverage Marks:')
print(df[['Maths','Science','English']].mean())

# Top performing student
top_student = df.loc[df['Total'].idxmax()]
print('Top Performing Student:')
print(top_student)

# Plot average marks subject-wise
subjects = ['Maths', 'Science', 'English']
avg_marks = df[subjects].mean()

plt.figure(figsize=(6,4))
plt.bar(subjects, avg_marks)
plt.xlabel('Subjects')
plt.ylabel('Average Marks')
plt.title('Average Marks by Subject')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Name        10 non-null     object
#  2   Maths       10 non-null     int64
#  3   Science     10 non-null     int64
#  4   English     10 non-null     int64
#  5   Total       10 non-null     int64
#  6   Average     10 non-null     float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 692.0+ bytes
# None
#
# Average Marks:
# Maths      80.6
# Science    81.2
# English    79.5
# dtype: float64
# Top Performing Student:
# Student_ID         107
# Name          Gayathri
# Maths               95
# Science             94
# English             96
# Total              285
# Average           95.0
# Name: 6, dtype: object
